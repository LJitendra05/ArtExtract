# %%
import sys
print(sys.executable)
# Out:
# d:\GSoC\Paint Extract\.venv\Scripts\python.exe

# %%
import torch

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.2.2+cpu
# False
